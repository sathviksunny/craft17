# %%
#!/usr/bin/env python2
# -*- coding: utf-8 -*-
"""
Created on Sat Aug 26 12:07:21 2017

@author: root
"""

import requests
from bs4 import BeautifulSoup


uda_link="https://in.udacity.com/courses/all/"
#sera_url="https://www.coursera.org/courses?languages=en&query="
#edx_url="https://www.edx.org/course?search_query="
#k=input("Enter your field? ")
#j=k.split()

'''for i in j:
	sera_url= sera_url + "+" + i
	edx_url	= edx_url + "+" + i
print(sera_url)	


r=requests.get(sera_url)
m=requests.get(edx_url)

soup1=BeautifulSoup(r.content)
soup2=BeautifulSoup(m.content)
'''
a=[]
b=[]
u=requests.get(uda_link)
soup3=BeautifulSoup(u.content)
'''
for link in soup1.find_all("a"):
	#print("<a href='%s'>%s</a>" %(link.get("href"),link.text))
	print(("%s :"+"%s")%(link.text,link.get("href")))
	
for link in soup2.find_all("a"):
	#print("<a href='%s'>%s</a>" %(link.get("href"),link.text))
	a=("%s :"+" %s"+"%s")%(link.text,"https://www.edx.org/",link.get("href"))
	print(a.strip("<").strip(">"))
'''

for span_dat in soup3.find_all("div",attrs={'class':'col-sm-4'}):
    a.append(span_dat.text.strip() )

for span_dat in soup3.find_all("div",attrs={'class':'col-sm-8'}):
    b.append(span_dat.text.strip() )
# Out:
# Asynchronous JavaScript Requests:
# https://www.udacity.com/course/asynchronous-javascript-requests--ud109?utm_medium=referral&utm_campaign=api
#
#
# C++ For Programmers:
# https://www.udacity.com/course/c-for-programmers--ud210?utm_medium=referral&utm_campaign=api
#
#
# Introduction to Python:
# https://www.udacity.com/course/introduction-to-python--ud1110?utm_medium=referral&utm_campaign=api
#
#
# Artificial Intelligence:
# https://www.udacity.com/course/artificial-intelligence--ud954?utm_medium=referral&utm_campaign=api
#
#
# Data Analysis and Visualization:
# https://www.udacity.com/course/data-analysis-and-visualization--ud404?utm_medium=referral&utm_campaign=api
#
#
# Localization Essentials:
# https://www.udacity.com/course/localization-essentials--ud610?utm_medium=referral&utm_campaign=api
#
#
# Human-Computer Interaction:
# https://www.udacity.com/course/human-computer-interaction--ud400?utm_medium=referral&utm_campaign=api
#
#
# Software Analysis & Testing:
# https://www.udacity.com/course/software-analysis-testing--ud333?utm_medium=referral&utm_campaign=api
#
#
# Cyber-Physical Systems Security:
# https://www.udacity.com/course/cyber-physical-systems-security--ud279?utm_medium=referral&utm_campaign=api
#
#
# Network Security:
# https://www.udacity.com/course/network-security--ud199?utm_medium=referral&utm_campaign=api
#
#
# Embedded Systems:
# https://www.udacity.com/course/embedded-systems--ud169?utm_medium=referral&utm_campaign=api
#
#
# Compilers: Theory and Practice:
# https://www.udacity.com/course/compilers-theory-and-practice--ud168?utm_medium=referral&utm_campaign=api
#
#
# Database Systems Concepts & Design:
# https://www.udacity.com/course/database-systems-concepts-design--ud150?utm_medium=referral&utm_campaign=api
#
#
# GitHub & Collaboration:
# https://www.udacity.com/course/github-collaboration--ud456?utm_medium=referral&utm_campaign=api
#
#
# ES6 - JavaScript Improved:
# https://www.udacity.com/course/es6-javascript-improved--ud356?utm_medium=referral&utm_campaign=api
#
#
# Version Control with Git:
# https://www.udacity.com/course/version-control-with-git--ud123?utm_medium=referral&utm_campaign=api
#
#
# Firebase Analytics: iOS:
# https://www.udacity.com/course/firebase-analytics-ios--ud353?utm_medium=referral&utm_campaign=api
#
#
# Firebase Analytics: Android:
# https://www.udacity.com/course/firebase-analytics-android--ud354?utm_medium=referral&utm_campaign=api
#
#
# Passwordless Login Solutions for iOS:
# https://www.udacity.com/course/passwordless-login-solutions-for-ios--ud1028?utm_medium=referral&utm_campaign=api
#
#
# Passwordless Login Solutions for Android:
# https://www.udacity.com/course/passwordless-login-solutions-for-android--ud357?utm_medium=referral&utm_campaign=api
#
#
# Shell Workshop:
# https://www.udacity.com/course/shell-workshop--ud206?utm_medium=referral&utm_campaign=api
#
#
# HTTP & Web Servers:
# https://www.udacity.com/course/http-web-servers--ud303?utm_medium=referral&utm_campaign=api
#
#
# VR Platforms & Applications:
# https://www.udacity.com/course/vr-platforms-applications--ud1015?utm_medium=referral&utm_campaign=api
#
#
# VR Design:
# https://www.udacity.com/course/vr-design--ud1016?utm_medium=referral&utm_campaign=api
#
#
# VR Software Development:
# https://www.udacity.com/course/vr-software-development--ud1014?utm_medium=referral&utm_campaign=api
#
#
# Server-Side Swift:
# https://www.udacity.com/course/server-side-swift--ud1031?utm_medium=referral&utm_campaign=api
#
#
# Android Basics: Networking:
# https://www.udacity.com/course/android-basics-networking--ud843?utm_medium=referral&utm_campaign=api
#
#
# Deploying a Hadoop Cluster:
# https://www.udacity.com/course/deploying-a-hadoop-cluster--ud1000?utm_medium=referral&utm_campaign=api
#
#
# Continuous Integration and Deployment:
# https://www.udacity.com/course/continuous-integration-and-deployment--ud1030?utm_medium=referral&utm_campaign=api
#
#
# Building iOS Interfaces:
# https://www.udacity.com/course/building-ios-interfaces--ud1027?utm_medium=referral&utm_campaign=api
#
#
# iOS Design Patterns:
# https://www.udacity.com/course/ios-design-patterns--ud1029?utm_medium=referral&utm_campaign=api
#
#
# Introduction to Virtual Reality:
# https://www.udacity.com/course/introduction-to-virtual-reality--ud1012?utm_medium=referral&utm_campaign=api
#
#
# VR Scenes and Objects:
# https://www.udacity.com/course/vr-scenes-and-objects--ud1013?utm_medium=referral&utm_campaign=api
#
#
# Swift for Beginners:
# https://www.udacity.com/course/swift-for-beginners--ud1022?utm_medium=referral&utm_campaign=api
#
#
# Swift for Developers:
# https://www.udacity.com/course/swift-for-developers--ud1025?utm_medium=referral&utm_campaign=api
#
#
# AutoLayout:
# https://www.udacity.com/course/autolayout--ud1026?utm_medium=referral&utm_campaign=api
#
#
# Scalable Microservices with Kubernetes:
# https://www.udacity.com/course/scalable-microservices-with-kubernetes--ud615?utm_medium=referral&utm_campaign=api
#
#
# Intro to Progressive Web Apps:
# https://www.udacity.com/course/intro-to-progressive-web-apps--ud811?utm_medium=referral&utm_campaign=api
#
#
# Web Accessibility:
# https://www.udacity.com/course/web-accessibility--ud891?utm_medium=referral&utm_campaign=api
#
#
# Google Maps APIs:
# https://www.udacity.com/course/google-maps-apis--ud864?utm_medium=referral&utm_campaign=api
#
#
# Technical Interview:
# https://www.udacity.com/course/technical-interview--ud513?utm_medium=referral&utm_campaign=api
#
#
# Android for Beginners:
# https://www.udacity.com/course/android-for-beginners--ud834?utm_medium=referral&utm_campaign=api
#
#
# Android Basics: User Input:
# https://www.udacity.com/course/android-basics-user-input--ud836?utm_medium=referral&utm_campaign=api
#
#
# Android Basics: Multiscreen Apps:
# https://www.udacity.com/course/android-basics-multiscreen-apps--ud839?utm_medium=referral&utm_campaign=api
#
#
# Android Basics: Networking:
# https://www.udacity.com/course/android-basics-networking--ud843?utm_medium=referral&utm_campaign=api
#
#
# Android Basics: Data Storage:
# https://www.udacity.com/course/android-basics-data-storage--ud845?utm_medium=referral&utm_campaign=api
#
#
# Problem Solving with Advanced Analytics:
# https://www.udacity.com/course/problem-solving-with-advanced-analytics--ud976?utm_medium=referral&utm_campaign=api
#
#
# Creating an Analytical Dataset:
# https://www.udacity.com/course/creating-an-analytical-dataset--ud977?utm_medium=referral&utm_campaign=api
#
#
# Classification Models:
# https://www.udacity.com/course/classification-models--ud978?utm_medium=referral&utm_campaign=api
#
#
# Intro to JavaScript:
# https://www.udacity.com/course/intro-to-javascript--ud803?utm_medium=referral&utm_campaign=api
#
#
# New Android Fundamentals:
# https://www.udacity.com/course/new-android-fundamentals--ud851?utm_medium=referral&utm_campaign=api
#
#
# Developing Android Apps:
# https://www.udacity.com/course/developing-android-apps--ud853?utm_medium=referral&utm_campaign=api
#
#
# Advanced Android App Development:
# https://www.udacity.com/course/advanced-android-app-development--ud855?utm_medium=referral&utm_campaign=api
#
#
# Gradle for Android and Java:
# https://www.udacity.com/course/gradle-for-android-and-java--ud867?utm_medium=referral&utm_campaign=api
#
#
# Google Location Services on Android:
# https://www.udacity.com/course/google-location-services-on-android--ud876-1?utm_medium=referral&utm_campaign=api
#
#
# Google Analytics for Android:
# https://www.udacity.com/course/google-analytics-for-android--ud876-2?utm_medium=referral&utm_campaign=api
#
#
# Monetize Your Android App with Ads:
# https://www.udacity.com/course/monetize-your-android-app-with-ads--ud876-3?utm_medium=referral&utm_campaign=api
#
#
# Add Google Maps to your Android App:
# https://www.udacity.com/course/add-google-maps-to-your-android-app--ud876-4?utm_medium=referral&utm_campaign=api
#
#
# Android Performance:
# https://www.udacity.com/course/android-performance--ud825?utm_medium=referral&utm_campaign=api
#
#
# Material Design for Android Developers:
# https://www.udacity.com/course/material-design-for-android-developers--ud862?utm_medium=referral&utm_campaign=api
#
#
# Android Wear Development:
# https://www.udacity.com/course/android-wear-development--ud875A?utm_medium=referral&utm_campaign=api
#
#
# Android TV and Google Cast Development:
# https://www.udacity.com/course/android-tv-and-google-cast-development--ud875B?utm_medium=referral&utm_campaign=api
#
#
# Android Auto Development:
# https://www.udacity.com/course/android-auto-development--ud875C?utm_medium=referral&utm_campaign=api
#
#
# Firebase Essentials For Android:
# https://www.udacity.com/course/firebase-essentials-for-android--ud009?utm_medium=referral&utm_campaign=api
#
#
# Get Your Startup Started:
# https://www.udacity.com/course/get-your-startup-started--ud806?utm_medium=referral&utm_campaign=api
#
#
# Product Design:
# https://www.udacity.com/course/product-design--ud509?utm_medium=referral&utm_campaign=api
#
#
# App Monetization:
# https://www.udacity.com/course/app-monetization--ud518?utm_medium=referral&utm_campaign=api
#
#
# Rapid Prototyping:
# https://www.udacity.com/course/rapid-prototyping--ud723?utm_medium=referral&utm_campaign=api
#
#
# App Marketing:
# https://www.udacity.com/course/app-marketing--ud719?utm_medium=referral&utm_campaign=api
#
#
# 2D Game Development with libGDX:
# https://www.udacity.com/course/2d-game-development-with-libgdx--ud405?utm_medium=referral&utm_campaign=api
#
#
# How to Make a Platformer Using libGDX:
# https://www.udacity.com/course/how-to-make-a-platformer-using-libgdx--ud406?utm_medium=referral&utm_campaign=api
#
#
# Engagement & Monetization | Mobile Games:
# https://www.udacity.com/course/engagement-monetization-mobile-games--ud407?utm_medium=referral&utm_campaign=api
#
#
# Client-Server Communication:
# https://www.udacity.com/course/client-server-communication--ud897?utm_medium=referral&utm_campaign=api
#
#
# Front End Frameworks:
# https://www.udacity.com/course/front-end-frameworks--ud894?utm_medium=referral&utm_campaign=api
#
#
# Offline Web Applications:
# https://www.udacity.com/course/offline-web-applications--ud899?utm_medium=referral&utm_campaign=api
#
#
# JavaScript Promises:
# https://www.udacity.com/course/javascript-promises--ud898?utm_medium=referral&utm_campaign=api
#
#
# Building High Conversion Web Forms:
# https://www.udacity.com/course/building-high-conversion-web-forms--ud890?utm_medium=referral&utm_campaign=api
#
#
# Web Tooling & Automation:
# https://www.udacity.com/course/web-tooling-automation--ud892?utm_medium=referral&utm_campaign=api
#
#
# Designing RESTful APIs:
# https://www.udacity.com/course/designing-restful-apis--ud388?utm_medium=referral&utm_campaign=api
#
#
# Writing READMEs:
# https://www.udacity.com/course/writing-readmes--ud777?utm_medium=referral&utm_campaign=api
#
#
# Intro to DevOps:
# https://www.udacity.com/course/intro-to-devops--ud611?utm_medium=referral&utm_campaign=api
#
#
# Intro to HTML and CSS:
# https://www.udacity.com/course/intro-to-html-and-css--ud304?utm_medium=referral&utm_campaign=api
#
#
# Intro to Computer Science:
# https://www.udacity.com/course/intro-to-computer-science--cs101?utm_medium=referral&utm_campaign=api
#
#
# Java Programming Basics:
# https://www.udacity.com/course/java-programming-basics--ud282?utm_medium=referral&utm_campaign=api
#
#
# Networking for Web Developers:
# https://www.udacity.com/course/networking-for-web-developers--ud256?utm_medium=referral&utm_campaign=api
#
#
# JavaScript Basics:
# https://www.udacity.com/course/javascript-basics--ud804?utm_medium=referral&utm_campaign=api
#
#
# Linux Command Line Basics:
# https://www.udacity.com/course/linux-command-line-basics--ud595?utm_medium=referral&utm_campaign=api
#
#
# How to Use Git and GitHub:
# https://www.udacity.com/course/how-to-use-git-and-github--ud775?utm_medium=referral&utm_campaign=api
#
#
# Programming Foundations with Python:
# https://www.udacity.com/course/programming-foundations-with-python--ud036?utm_medium=referral&utm_campaign=api
#
#
# Intro to iOS App Development with Swift:
# https://www.udacity.com/course/intro-to-ios-app-development-with-swift--ud585?utm_medium=referral&utm_campaign=api
#
#
# Intro to Relational Databases:
# https://www.udacity.com/course/intro-to-relational-databases--ud197?utm_medium=referral&utm_campaign=api
#
#
# Full Stack Foundations:
# https://www.udacity.com/course/full-stack-foundations--ud088?utm_medium=referral&utm_campaign=api
#
#
# Authentication & Authorization: OAuth:
# https://www.udacity.com/course/authentication-authorization-oauth--ud330?utm_medium=referral&utm_campaign=api
#
#
# Responsive Web Design Fundamentals:
# https://www.udacity.com/course/responsive-web-design-fundamentals--ud893?utm_medium=referral&utm_campaign=api
#
#
# Responsive Images:
# https://www.udacity.com/course/responsive-images--ud882?utm_medium=referral&utm_campaign=api
#
#
# Browser Rendering Optimization:
# https://www.udacity.com/course/browser-rendering-optimization--ud860?utm_medium=referral&utm_campaign=api
#
#
# Developing Scalable Apps in Python:
# https://www.udacity.com/course/developing-scalable-apps-in-python--ud858?utm_medium=referral&utm_campaign=api
#
#
# JavaScript Design Patterns:
# https://www.udacity.com/course/javascript-design-patterns--ud989?utm_medium=referral&utm_campaign=api
#
#
# Learn Backbone.js:
# https://www.udacity.com/course/learn-backbonejs--ud990?utm_medium=referral&utm_campaign=api
#
#
# JavaScript Testing:
# https://www.udacity.com/course/javascript-testing--ud549?utm_medium=referral&utm_campaign=api
#
#
# Configuring Linux Web Servers:
# https://www.udacity.com/course/configuring-linux-web-servers--ud299?utm_medium=referral&utm_campaign=api
#
#
# How to Build a Startup:
# https://www.udacity.com/course/how-to-build-a-startup--ep245?utm_medium=referral&utm_campaign=api
#
#
# Learn Swift Programming Syntax:
# https://www.udacity.com/course/learn-swift-programming-syntax--ud902?utm_medium=referral&utm_campaign=api
#
#
# UIKit Fundamentals:
# https://www.udacity.com/course/uikit-fundamentals--ud788?utm_medium=referral&utm_campaign=api
#
#
# iOS Networking with Swift:
# https://www.udacity.com/course/ios-networking-with-swift--ud421?utm_medium=referral&utm_campaign=api
#
#
# Grand Central Dispatch (GCD):
# https://www.udacity.com/course/grand-central-dispatch-gcd--ud576?utm_medium=referral&utm_campaign=api
#
#
# iOS Persistence and Core Data:
# https://www.udacity.com/course/ios-persistence-and-core-data--ud325?utm_medium=referral&utm_campaign=api
#
#
# Objective-C for Swift Developers:
# https://www.udacity.com/course/objective-c-for-swift-developers--ud1009?utm_medium=referral&utm_campaign=api
#
#
# Xcode Debugging:
# https://www.udacity.com/course/xcode-debugging--ud774?utm_medium=referral&utm_campaign=api
#
#
# How to Make an iOS App:
# https://www.udacity.com/course/how-to-make-an-ios-app--ud607?utm_medium=referral&utm_campaign=api
#
#
# A/B Testing:
# https://www.udacity.com/course/ab-testing--ud257?utm_medium=referral&utm_campaign=api
#
#
# A/B Testing (Certified Course):
# https://www.udacity.com/course/ab-testing-certified-course--ud257-certified?utm_medium=referral&utm_campaign=api
#
#
# Data Visualization and D3.js:
# https://www.udacity.com/course/data-visualization-and-d3js--ud507?utm_medium=referral&utm_campaign=api
#
#
# Intro to Machine Learning:
# https://www.udacity.com/course/intro-to-machine-learning--ud120?utm_medium=referral&utm_campaign=api
#
#
# Intro to Hadoop and MapReduce:
# https://www.udacity.com/course/intro-to-hadoop-and-mapreduce--ud617?utm_medium=referral&utm_campaign=api
#
#
# Real-Time Analytics with Apache Storm:
# https://www.udacity.com/course/real-time-analytics-with-apache-storm--ud381?utm_medium=referral&utm_campaign=api
#
#
# Intro to Data Analysis:
# https://www.udacity.com/course/intro-to-data-analysis--ud170?utm_medium=referral&utm_campaign=api
#
#
# Intro to Data Science:
# https://www.udacity.com/course/intro-to-data-science--ud359?utm_medium=referral&utm_campaign=api
#
#
# Web Development:
# https://www.udacity.com/course/web-development--cs253?utm_medium=referral&utm_campaign=api
#
#
# Web Accessibility:
# https://www.udacity.com/course/web-accessibility--ud891?utm_medium=referral&utm_campaign=api
#
#
# Object-Oriented JavaScript:
# https://www.udacity.com/course/object-oriented-javascript--ud015?utm_medium=referral&utm_campaign=api
#
#
# HTML5 Canvas:
# https://www.udacity.com/course/html5-canvas--ud292?utm_medium=referral&utm_campaign=api
#
#
# Intro to jQuery:
# https://www.udacity.com/course/intro-to-jquery--ud245?utm_medium=referral&utm_campaign=api
#
#
# Intro to AJAX:
# https://www.udacity.com/course/intro-to-ajax--ud110?utm_medium=referral&utm_campaign=api
#
#
# Intro to Artificial Intelligence:
# https://www.udacity.com/course/intro-to-artificial-intelligence--cs271?utm_medium=referral&utm_campaign=api
#
#
# Data Analysis with R:
# https://www.udacity.com/course/data-analysis-with-r--ud651?utm_medium=referral&utm_campaign=api
#
#
# UX Design for Mobile Developers:
# https://www.udacity.com/course/ux-design-for-mobile-developers--ud849?utm_medium=referral&utm_campaign=api
#
#
# Intro to Point & Click App Development:
# https://www.udacity.com/course/intro-to-point-click-app-development--ud162?utm_medium=referral&utm_campaign=api
#
#
# Developing Scalable Apps in Java:
# https://www.udacity.com/course/developing-scalable-apps-in-java--ud859?utm_medium=referral&utm_campaign=api
#
#
# Intro to Parallel Programming:
# https://www.udacity.com/course/intro-to-parallel-programming--cs344?utm_medium=referral&utm_campaign=api
#
#
# Intro to Descriptive Statistics:
# https://www.udacity.com/course/intro-to-descriptive-statistics--ud827?utm_medium=referral&utm_campaign=api
#
#
# Intro to Inferential Statistics:
# https://www.udacity.com/course/intro-to-inferential-statistics--ud201?utm_medium=referral&utm_campaign=api
#
#
# Introduction to Operating Systems:
# https://www.udacity.com/course/introduction-to-operating-systems--ud923?utm_medium=referral&utm_campaign=api
#
#
# Intro to Information Security:
# https://www.udacity.com/course/intro-to-information-security--ud459?utm_medium=referral&utm_campaign=api
#
#
# Advanced Operating Systems:
# https://www.udacity.com/course/advanced-operating-systems--ud189?utm_medium=referral&utm_campaign=api
#
#
# Computability, Complexity & Algorithms:
# https://www.udacity.com/course/computability-complexity-algorithms--ud061?utm_medium=referral&utm_campaign=api
#
#
# Knowledge-Based AI: Cognitive Systems:
# https://www.udacity.com/course/knowledge-based-ai-cognitive-systems--ud409?utm_medium=referral&utm_campaign=api
#
#
# Machine Learning for Trading:
# https://www.udacity.com/course/machine-learning-for-trading--ud501?utm_medium=referral&utm_campaign=api
#
#
# High Performance Computer Architecture:
# https://www.udacity.com/course/high-performance-computer-architecture--ud007?utm_medium=referral&utm_campaign=api
#
#
# High Performance Computing:
# https://www.udacity.com/course/high-performance-computing--ud281?utm_medium=referral&utm_campaign=api
#
#
# Health Informatics in the Cloud:
# https://www.udacity.com/course/health-informatics-in-the-cloud--ud809?utm_medium=referral&utm_campaign=api
#
#
# Big Data Analytics in Healthcare:
# https://www.udacity.com/course/big-data-analytics-in-healthcare--ud758?utm_medium=referral&utm_campaign=api
#
#
# Computer Networking:
# https://www.udacity.com/course/computer-networking--ud436?utm_medium=referral&utm_campaign=api
#
#
# Computational Photography:
# https://www.udacity.com/course/computational-photography--ud955?utm_medium=referral&utm_campaign=api
#
#
# Software Development Process:
# https://www.udacity.com/course/software-development-process--ud805?utm_medium=referral&utm_campaign=api
#
#
# Software Architecture & Design:
# https://www.udacity.com/course/software-architecture-design--ud821?utm_medium=referral&utm_campaign=api
#
#
# Artificial Intelligence for Robotics:
# https://www.udacity.com/course/artificial-intelligence-for-robotics--cs373?utm_medium=referral&utm_campaign=api
#
#
# Introduction to Computer Vision:
# https://www.udacity.com/course/introduction-to-computer-vision--ud810?utm_medium=referral&utm_campaign=api
#
#
# Educational Technology:
# https://www.udacity.com/course/educational-technology--ud915?utm_medium=referral&utm_campaign=api
#
#
# Reinforcement Learning:
# https://www.udacity.com/course/reinforcement-learning--ud600?utm_medium=referral&utm_campaign=api
#
#
# Linear Algebra Refresher Course:
# https://www.udacity.com/course/linear-algebra-refresher-course--ud953?utm_medium=referral&utm_campaign=api
#
#
# Data Wrangling with MongoDB:
# https://www.udacity.com/course/data-wrangling-with-mongodb--ud032?utm_medium=referral&utm_campaign=api
#
#
# Model Building and Validation:
# https://www.udacity.com/course/model-building-and-validation--ud919?utm_medium=referral&utm_campaign=api
#
#
# Deep Learning:
# https://www.udacity.com/course/deep-learning--ud730?utm_medium=referral&utm_campaign=api
#
#
# Intro to the Design of Everyday Things:
# https://www.udacity.com/course/intro-to-the-design-of-everyday-things--design101?utm_medium=referral&utm_campaign=api
#
#
# Mobile Web Development:
# https://www.udacity.com/course/mobile-web-development--cs256?utm_medium=referral&utm_campaign=api
#
#
# Website Performance Optimization:
# https://www.udacity.com/course/website-performance-optimization--ud884?utm_medium=referral&utm_campaign=api
#
#
# Make Your Own 2048:
# https://www.udacity.com/course/make-your-own-2048--ud248?utm_medium=referral&utm_campaign=api
#
#
# HTML5 Game Development:
# https://www.udacity.com/course/html5-game-development--cs255?utm_medium=referral&utm_campaign=api
#
#
# Applied Cryptography:
# https://www.udacity.com/course/applied-cryptography--cs387?utm_medium=referral&utm_campaign=api
#
#
# Intro to Statistics:
# https://www.udacity.com/course/intro-to-statistics--st101?utm_medium=referral&utm_campaign=api
#
#
# Intro Algebra Review:
# https://www.udacity.com/course/intro-algebra-review--ma004?utm_medium=referral&utm_campaign=api
#
#
# College Algebra:
# https://www.udacity.com/course/college-algebra--ma008?utm_medium=referral&utm_campaign=api
#
#
# Visualizing Algebra:
# https://www.udacity.com/course/visualizing-algebra--ma006?utm_medium=referral&utm_campaign=api
#
#
# Software Testing:
# https://www.udacity.com/course/software-testing--cs258?utm_medium=referral&utm_campaign=api
#
#
# Intro to Algorithms:
# https://www.udacity.com/course/intro-to-algorithms--cs215?utm_medium=referral&utm_campaign=api
#
#
# Interactive 3D Graphics:
# https://www.udacity.com/course/interactive-3d-graphics--cs291?utm_medium=referral&utm_campaign=api
#
#
# Programming Languages:
# https://www.udacity.com/course/programming-languages--cs262?utm_medium=referral&utm_campaign=api
#
#
# Design of Computer Programs:
# https://www.udacity.com/course/design-of-computer-programs--cs212?utm_medium=referral&utm_campaign=api
#
#
# Differential Equations in Action:
# https://www.udacity.com/course/differential-equations-in-action--cs222?utm_medium=referral&utm_campaign=api
#
#
# Software Debugging:
# https://www.udacity.com/course/software-debugging--cs259?utm_medium=referral&utm_campaign=api
#
#
# Intro to Theoretical Computer Science:
# https://www.udacity.com/course/intro-to-theoretical-computer-science--cs313?utm_medium=referral&utm_campaign=api
#
#
# Machine Learning:
# https://www.udacity.com/course/machine-learning--ud262?utm_medium=referral&utm_campaign=api
#
#
# Intro to Physics:
# https://www.udacity.com/course/intro-to-physics--ph100?utm_medium=referral&utm_campaign=api
#
#
# Tales from the Genome:
# https://www.udacity.com/course/tales-from-the-genome--bio110?utm_medium=referral&utm_campaign=api
#
#
# Intro to Psychology:
# https://www.udacity.com/course/intro-to-psychology--ps001?utm_medium=referral&utm_campaign=api
#
#
# OMSCS Student Orientation:
# https://www.udacity.com/course/omscs-student-orientation--gt101?utm_medium=referral&utm_campaign=api
#
#
# GT - Refresher - Advanced OS:
# https://www.udacity.com/course/gt-refresher-advanced-os--ud098?utm_medium=referral&utm_campaign=api
#
#
# Objective-C for Swift Developers:
# https://www.udacity.com/course/objective-c-for-swift-developers--ud1009?utm_medium=referral&utm_campaign=api
#
#
# Dynamic Web Applications with Sinatra:
# https://www.udacity.com/course/dynamic-web-applications-with-sinatra--ud268?utm_medium=referral&utm_campaign=api
#
#
# The MVC Pattern in Ruby:
# https://www.udacity.com/course/the-mvc-pattern-in-ruby--ud270?utm_medium=referral&utm_campaign=api
#
#
# Deploying Applications with Heroku:
# https://www.udacity.com/course/deploying-applications-with-heroku--ud272?utm_medium=referral&utm_campaign=api
#
#
# Time Series Forecasting:
# https://www.udacity.com/course/time-series-forecasting--ud980?utm_medium=referral&utm_campaign=api
#
#
# A/B Testing:
# https://www.udacity.com/course/ab-testing--ud979?utm_medium=referral&utm_campaign=api
#
#
# Segmentation and Clustering:
# https://www.udacity.com/course/segmentation-and-clustering--ud981?utm_medium=referral&utm_campaign=api
#
#
# Data Visualization in Tableau:
# https://www.udacity.com/course/data-visualization-in-tableau--ud1006?utm_medium=referral&utm_campaign=api
#
#
# Introduction to Health Informatics:
# https://www.udacity.com/course/introduction-to-health-informatics--ud835?utm_medium=referral&utm_campaign=api
#
#
# Android for Beginners:
# https://www.udacity.com/course/android-for-beginners--ud834?utm_medium=referral&utm_campaign=api
#
#
# Android Basics: User Input:
# https://www.udacity.com/course/android-basics-user-input--ud836?utm_medium=referral&utm_campaign=api
#
#
# Firebase in a Weekend by Google: Android:
# https://www.udacity.com/course/firebase-in-a-weekend-by-google-android--ud0352?utm_medium=referral&utm_campaign=api
#
#
# Firebase in a Weekend by Google: iOS:
# https://www.udacity.com/course/firebase-in-a-weekend-by-google-ios--ud0351?utm_medium=referral&utm_campaign=api

# %%
print course
# Out:
# {u'subtitle': u'Building a Realtime Chat App', u'key': u'ud0351', u'image': u'https://lh3.googleusercontent.com/vi7wJNqhqNgJ4BnJMdN01FTrbxDI3wq0_qPVOis6q9dFWnllJXKsm8f_1B-y4PISE2UJ0EJ1fSnGMLnJ01o=s0#w=1524&h=888', u'expected_learning': u'If you are an iOS developer and your app needs any of the following features:\n\nOnline data storage\nReal-time synchronization between many users\nAuthentication for Email/Password as well as OAuth providers\nData permissions and security\nOffline access to data\n\nThis is the course for you!\n\nFirebase is a gentle but very powerful introduction to storing and managing data. With just a few lines of code, you can read and write almost any data you could dream up from your own custom Firebase backend.\n\nFurthermore, Firebase has a generous free plan that lets you start making hosted apps with multiple users immediately.', u'featured': False, u'project_description': u'', u'faq': u'', u'teaser_video': {u'youtube_url': u''}, u'title': u'Firebase in a Weekend by Google: iOS', u'related_degree_keys': [], u'required_knowledge': u'You need to have proficiency in building an iOS mobile application, including experience in basic command line, calling a web or cloud API, working with the view controller life cycle, using multiple view controllers, and working with UITableViewController (iOS Developer Nanodegree or equivalent level). Familiarity working with a web service from iOS, using Core Data, or building apps that use databases will also be helpful.', u'syllabus': u"Lesson 1 - Saturday: Why Choose Firebase, Creating a Firebase Project, Reading and Writing using Firebase Realtime Database, Firebase Security Rules, Firebase Authentication\nLesson 2 - Sunday Funday: Firebase Storage for user uploaded files, Securing uploaded files with Firebase's Storage rules, Leveraging Firebase Analytics to Improve User Engagement, Sending Notifications, Using Firebase Remote Config", u'new_release': False, u'homepage': u'https://www.udacity.com/course/firebase-in-a-weekend-by-google-ios--ud0351?utm_medium=referral&utm_campaign=api', u'project_name': u'', u'full_course_available': False, u'instructors': [{u'bio': u'Jarrod is no stranger to trying new things for the sake of education: both a self-starter and advocate for reinventing the ways we learn, he first started challenging the status quo when he helped create virtual science labs for middle school students at the HudsonAlpha Institute for Biotechnology. While studying Computer Science at the University of Alabama in Huntsville, he started supplementing his college curriculum with online courseware, and he has never looked back. He holds a BS in Computer Science from the University of Alabama in Huntsville.', u'image': u'https://lh4.ggpht.com/mC-YTFs8cIEoJR5IbuKo8pIVuJnZ7PY0IcZfgKsz22exBWabmnzyre8V0j8sURASRVM-2ao_-1hTLSgEsLI=s0#w=750&h=750', u'name': u'Jarrod Parkes'}], u'affiliates': [], u'tracks': [], u'banner_image': u'https://lh3.googleusercontent.com/W1lvKbUvicbC32cLQSfypx-Z-PxFznJ-_XLFjzKWbBhS1NpYVHSyCN7alFyUGjFWpFVv6xXp1HgIrI9Zgg=s0#w=600&h=600', u'short_summary': u'This course will teach you when and why to choose Firebase as a backend for your iOS application.', u'slug': u'firebase-in-a-weekend-by-google-ios--ud0351', u'starter': False, u'level': u'intermediate', u'expected_duration_unit': u'days', u'summary': u'In this course, you\u2019ll learn how to use Firebase from the experts at Google. Firebase is an app development platform that provides developers with a variety of tools and a scalable infrastructure so that you can quickly build high quality apps.\n\n\nIn this course, you\u2019ll build FriendlyChat, a realtime text and picture chat application.\n\n\nTo start, you\u2019ll see how easy it is to read and write data to Firebase. After that, you\u2019ll learn how to let users login with their email or Google account. You\u2019ll then learn how to use Firebase\u2019s Security and Rules language to secure and add permissions to your data.\n\n\nIn ...
