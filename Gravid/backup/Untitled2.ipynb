# %%
#!/usr/bin/env python2
# -*- coding: utf-8 -*-
"""
Created on Sat Aug 26 12:07:21 2017

@author: root
"""

import requests
from bs4 import BeautifulSoup


uda_link="https://in.udacity.com/courses/all/"

u=requests.get(uda_link)
soup3=BeautifulSoup(u.content)

    
a=[]
b=[]

for span_dat in soup3.find_all("div",attrs={'class':'col-sm-4'}):
    a.append(span_dat.text.strip() )

for span_dat in soup3.find_all("div",attrs={'class':'col-sm-8'}):
    b.append(span_dat.text.strip() )

# %%
t = [ ]  
for ax in a:  
        for bx in b:  
                t.append((ax,bx))  
print t
# Out:
# [(u'advanced', u'Self-Driving Car Engineer Nanodegree'), (u'advanced', u'React Nanodegree\n\nNew'), (u'advanced', u'Intro to Programming Nanodegree\n\nNew'), (u'advanced', u'Become an iOS Developer'), (u'advanced', u'Associate Android Developer Fast Track\n\nNew'), (u'advanced', u'Front-End Web Developer Nanodegree'), (u'advanced', u'Android Basics Nanodegree by Google'), (u'advanced', u'Android Developer Nanodegree by Google'), (u'advanced', u'Artificial Intelligence Nanodegree'), (u'advanced', u'Business Analyst Nanodegree'), (u'advanced', u'Robotics Nanodegree'), (u'advanced', u'VR Developer Nanodegree\n\nNew'), (u'advanced', u'Full Stack Web Developer Nanodegree'), (u'advanced', u'Digital Marketing Nanodegree'), (u'advanced', u'Machine Learning Engineer Nanodegree'), (u'advanced', u'Data Analyst Nanodegree'), (u'advanced', u'Localization Essentials\n\nNew'), (u'advanced', u'Android Basics: Data Storage\n\nNew'), (u'advanced', u'Technical Interview\n\nNew'), (u'advanced', u'Intro to JavaScript\n\nNew'), (u'advanced', u'Monetize Your Android App with Ads'), (u'advanced', u'Android Basics: User Input\n\nNew'), (u'advanced', u'How to Make an iOS App'), (u'advanced', u'Database Systems Concepts & Design'), (u'advanced', u'Compilers: Theory and Practice'), (u'advanced', u'Network Security'), (u'advanced', u'Cyber-Physical Systems Security'), (u'advanced', u'Software Analysis & Testing'), (u'advanced', u'Machine Learning for Trading'), (u'advanced', u'High Performance Computing'), (u'advanced', u'Health Informatics in the Cloud'), (u'advanced', u'Computational Photography'), (u'advanced', u'Software Development Process'), (u'advanced', u'Software Architecture & Design'), (u'advanced', u'Artificial Intelligence for Robotics'), (u'advanced', u'Educational Technology'), (u'advanced', u'Reinforcement Learning'), (u'advanced', u'Linear Algebra Refresher Course'), (u'advanced', u'Data Wrangling with MongoDB'), (u'advanced', u'GitHub & Collaboration\n\nNew'), (u'advanced', u'Model Building and Validation'), (u'advanced', u'Intro to the Design of Everyday Things'), (u'advanced', u'Website Performance Optimization'), (u'advanced', u'Make Your Own 2048'), (u'advanced', u'Intro to Statistics'), (u'advanced', u'Intro Algebra Review'), (u'advanced', u'Visualizing Algebra'), (u'advanced', u'Software Testing'), (u'advanced', u'Interactive 3D Graphics'), (u'advanced', u'Programming Languages'), (u'advanced', u'Design of Computer Programs'), (u'advanced', u'Intro to Theoretical Computer Science'), (u'advanced', u'Intro to Physics'), (u'advanced', u'OMSCS Student Orientation'), (u'advanced', u'GT - Refresher - Advanced OS\n\nNew'), (u'advanced', u'Statistics'), (u'advanced', u'Engagement & Monetization | Mobile Games\n\nNew'), (u'advanced', u'A/B Testing (Certified Course)'), (u'advanced', u'Developing Android Apps'), (u'advanced', u'Front End Frameworks\n\nNew'), (u'advanced', u'Deploying a Hadoop Cluster'), (u'advanced', u'Networking for Web Developers'), (u'advanced', u'Scalable Microservices with Kubernetes\n\nNew'), (u'advanced', u'Intro to Progressive Web Apps\n\nNew'), (u'advanced', u'Java Programming Basics\n\nNew'), (u'advanced', u'Android Basics: Networking\n\nNew'), (u'advanced', u'Creating an Analytical Dataset'), (u'advanced', u'Classification Models'), (u'advanced', u'Intro to Java Programming'), (u'advanced', u'Intro to Relational Databases'), (u'advanced', u'Full Stack Foundations'), (u'advanced', u'Responsive Images'), (u'advanced', u'Browser Rendering Optimization'), (u'advanced', u'Firebase in a Weekend: iOS\n\nNew'), (u'advanced', u'Firebase in a Weekend: Android\n\nNew'), (u'advanced', u'iOS Networking with Swift'), (u'advanced', u'Big Data Analytics in Healthcare\n\nNew'), (u'advanced', u'Time Series Forecasting'), (u'advanced', u'Segmentation and Clustering'), (u'advanced', u'Data Visualization in Tableau\n\nNew'), (u'advanced', u'Introduction to Virtual Reality'), (u'advanced', u'VR Scenes and Objects'), (u'advanced', u'VR  ...
